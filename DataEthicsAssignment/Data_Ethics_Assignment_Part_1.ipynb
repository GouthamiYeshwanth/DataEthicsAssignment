# %%
import pandas as pd
import numpy as np
import seaborn
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime, date 
import sklearn

# %% [markdown]
# # Assignment Part 1

# %% [markdown]
# Read the Dataset provided

# %%
df = pd.read_excel('DataEthicsAssignmentDataset.xlsx')
df.head()
# Out:
#      Order  Member                                                SKU  \
# 0  6422558  M27458  15669789, 15669830, 34993978, 15669856, 775378...
# 1  6422636  M39021  7580802, 15668453, 15668375, 15668379, 1566976...
# 2  6423338  M36366  15668469, 15668478, 7586314, 15669800, 1566978...
# 3  6423534  M25900              34987356, 15670251, 7585573, 34992815
# 4  6423959  M57354               34989501, 7580811, 7569799, 34938526
#
#    Created On                                        Description  \
# 0  28-09-2014  Boiled Rice, Other Rice Products, Mosquito Rep...
# 1  28-09-2014  Sunflower Oils, Brinjals, Root Vegetables, Oth...
# 2  28-09-2014  Beans, Banana, Snacky Nuts, Cashews, Millet fl...
# 3  28-09-2014        Facial Tissues, Organic F&V, Cakes, Cookies
# 4  29-09-2014  Other Pulses, Sunflower Oils, Snacks, Other Sw...
#
#   Member's Full Name                                 Member's Address  \
# 0    Melissa Nielsen         3260 Scott Fords, Port Richard, KY 71319
# 1   Kevin Pennington            19919 Lara Ferry, Jonesfurt, WY 70455
# 2    Jessica Nichols          43026 Fisher Mount, New Karen, KY 94332
# 3     Jessica Guzman  5071 Bell Knolls, Port Gabriellaburgh, AL 69223
# 4      Matthew Davis  44842 Pamela Street, Port Natashafort, AL 87144
#
#                Member's Email Member's Phone Number Member's Gender  \
# 0          tina64@example.org         (981)315-0970            Male
# 1      lisahorton@example.com     (808)745-0768x733            Male
# 2  gordoncourtney@example.com   (912)707-8569x14006            Male
# 3           ibell@example.com         (722)989-7498          Female
# 4         nancy96@example.net     972-960-4816x5421            Male
#
#   Member's Date of Birth Member's Membership Level  Member's Purchase History  \
# 0             16-02-1996                    Silver                          0
# 1             30-04-1911                      Gold                          8
# 2    1924-10-02 00:00:00                    Bronze                          3
# 3    1953-08-01 00:00:00                      Gold                          7
# 4    1951-11-12 00:00:00                    Bronze                          5
#
#    Order Value Payment Method  \
# 0          620         PayPal
# 1          618    Credit Card
# 2          295           Cash
# 3          881    Credit Card
# 4          595           Cash
#
#                                     Delivery Address Order Status  \
# 0                   Unit 9405 Box 3979, DPO AA 03716      Shipped
# 1                   PSC 8209, Box 7092, APO AP 28287    Delivered
# 2  666 Jennifer Mills Suite 089, New Travis, VI 9...      Shipped
# 3  0279 Jason Forges Apt. 497, Andrewsborough, NV...      Pending
# 4    5038 Shane Rue Apt. 867, East Kenneth, AK 08214    Delivered
#
#    Credit Card Number
# 0                 NaN
# 1        3.509367e+15
# 2                 NaN
# 3        2.581849e+15
# 4                 NaN

# %% [markdown]
# check how many records are present and how many features are present

# %%
df.shape
# Out:
# (8387, 18)

# %% [markdown]
# Check the data in each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8387 entries, 0 to 8386
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Order                      8387 non-null   int64
#  1   Member                     8387 non-null   object
#  2   SKU                        8387 non-null   object
#  3   Created On                 8387 non-null   object
#  4   Description                8387 non-null   object
#  5   Member's Full Name         8387 non-null   object
#  6   Member's Address           8387 non-null   object
#  7   Member's Email             8387 non-null   object
#  8   Member's Phone Number      8387 non-null   object
#  9   Member's Gender            8387 non-null   object
#  10  Member's Date of Birth     8387 non-null   object
#  11  Member's Membership Level  8387 non-null   object
#  12  Member's Purchase History  8387 non-null   int64
#  13  Order Value                8387 non-null   int64
#  14  Payment Method             8387 non-null   object
#  15  Delivery Address           8387 non-null   object
#  16  Order Status               8387 non-null   object
#  17  Credit Card Number         2763 non-null   float64
# dtypes: float64(1), int64(3), object(14)
# memory usage: 1.2+ MB

# %% [markdown]
# We see that date columns are all object, we shall convert them into Date format

# %% [markdown]
# ### Data Pre processing

# %% [markdown]
# convert the object datatype for the columns "Created On" and "Date of Birth" to datetime

# %%
#Convert the Created Date to Date format
df['corrected_Created_date'] = pd.to_datetime(df['Created On'], format='%d-%m-%Y',errors='coerce')

# %%
#Convert the Created Date to Date format
df['Created_date_yy'] = pd.to_datetime(df['Created On'], format='%Y-%m-%d',errors='coerce')

# %%
df.corrected_Created_date.fillna(df.Created_date_yy, inplace=True)

# %%
# drop the original column which has object data type
df.drop(['Created_date_yy'],inplace=True, axis=1)

# %%
#Convert the Date of birth to Date format
df['corrected_members_dob'] = pd.to_datetime(df['Member\'s Date of Birth'], format='%d-%m-%Y',errors='coerce')
df['member_dob_yy'] = pd.to_datetime(df['Member\'s Date of Birth'], format='%Y-%m-%d',errors='coerce')
df.corrected_members_dob.fillna(df.member_dob_yy, inplace=True)
df.drop(['member_dob_yy'],inplace=True, axis=1)

# %%
# Find the total items bought by each members
df['Total_Items'] = [len(str(x).split(',')) for x in df.SKU]

# %%
# Calculate the age of the customers from Date of birth
def age(born):
    #born = datetime.strptime(born, "%Y/%m/%d").date()
    today = date.today()
    return today.year - born.year - ((today.month, 
                                      today.day) < (born.month, 
                                                    born.day))

df['Age'] = df['corrected_members_dob'].apply(age)

# %% [markdown]
# view the statistics of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8387 entries, 0 to 8386
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Order                      8387 non-null   int64
#  1   Member                     8387 non-null   object
#  2   SKU                        8387 non-null   object
#  3   Created On                 8387 non-null   object
#  4   Description                8387 non-null   object
#  5   Member's Full Name         8387 non-null   object
#  6   Member's Address           8387 non-null   object
#  7   Member's Email             8387 non-null   object
#  8   Member's Phone Number      8387 non-null   object
#  9   Member's Gender            8387 non-null   object
#  10  Member's Date of Birth     8387 non-null   object
#  11  Member's Membership Level  8387 non-null   object
#  12  Member's Purchase History  8387 non-null   int64
#  13  Order Value                8387 non-null   int64
#  14  Payment Method             8387 non-null   object
#  15  Delivery Address           8387 non-null   object
#  16  Order Status               8387 non-null   object
#  17  Credit Card Number         2763 non-null   float64
#  18  corrected_Created_date     8387 non-null   datetime64[ns]
#  19  corrected_members_dob      8387 non-null   datetime64[ns]
#  20  Total_Items                8387 non-null   int64
#  21  Age                        8387 non-null   int64
# dtypes: datetime64[ns](2), float64(1), int64(5), object(14)
# memory usage: 1.4+ MB

# %% [markdown]
# ## understand the buying pattern and trends of the existing customers

# %% [markdown]
# Filter out only those columns that are needed to find the buying pattern

# %%
filt_df = df[['Order','Member','corrected_Created_date','Description','Total_Items','Member\'s Full Name','Member\'s Address',
             'Member\'s Gender','corrected_members_dob','Age','Member\'s Membership Level','Member\'s Purchase History',
             'Order Value','Payment Method','Order Status']]

# %%
seaborn.pairplot(filt_df, hue ='Member\'s Gender')

# %% [markdown]
# From the pair plot of the Orders, we get to know that both Female and Male customers have placed similar number of orders. The Female customers have produced slightly more Order value

# %% [markdown]
# ###### Spending pattern of customer based on number of orders placed on each day

# %%
pd.pivot_table(filt_df,values='Order',index='corrected_Created_date',columns='Member',aggfunc='count')
# Out:
# Member                  M04158  M08075  M09303  M09736  M12050  M12127  \
# corrected_Created_date
# 2011-12-03                 NaN     NaN     NaN     NaN     NaN     NaN
# 2011-12-04                 NaN     NaN     NaN     NaN     NaN     NaN
# 2011-12-07                 NaN     NaN     NaN     NaN     NaN     NaN
# 2011-12-08                 NaN     NaN     NaN     NaN     NaN     NaN
# 2011-12-13                 NaN     NaN     NaN     NaN     NaN     NaN
# ...                        ...     ...     ...     ...     ...     ...
# 2014-10-02                 NaN     NaN     NaN     NaN     NaN     NaN
# 2014-10-03                 NaN     NaN     NaN     NaN     NaN     NaN
# 2014-10-04                 NaN     NaN     NaN     NaN     NaN     NaN
# 2014-10-05                 NaN     NaN     NaN     NaN     NaN     NaN
# 2014-10-06                 NaN     1.0     1.0     NaN     NaN     NaN
#
# Member                  M14746  M16218  M16611  M18732  ...  M78720  M82651  \
# corrected_Created_date                                  ...
# 2011-12-03                 NaN     NaN     NaN     NaN  ...     NaN     NaN
# 2011-12-04                 NaN     NaN     NaN     NaN  ...     NaN     NaN
# 2011-12-07                 NaN     NaN     NaN     NaN  ...     NaN     NaN
# 2011-12-08                 NaN     NaN     NaN     NaN  ...     NaN     NaN
# 2011-12-13                 NaN     NaN     NaN     NaN  ...     NaN     NaN
# ...                        ...     ...     ...     ...  ...     ...     ...
# 2014-10-02                 1.0     NaN     NaN     NaN  ...     NaN     NaN
# 2014-10-03                 NaN     NaN     NaN     NaN  ...     NaN     NaN
# 2014-10-04                 NaN     NaN     NaN     NaN  ...     NaN     1.0
# 2014-10-05                 NaN     NaN     NaN     1.0  ...     NaN     NaN
# 2014-10-06                 NaN     NaN     NaN     NaN  ...     NaN     NaN
#
# Member                  M84827  M86304  M86572  M90375  M91098  M96365  \
# corrected_Created_date
# 2011-12-03                 NaN     NaN     NaN     NaN     NaN     NaN
# 2011-12-04                 NaN     NaN     NaN     NaN     NaN     NaN
# 2011-12-07                 NaN     NaN     NaN     NaN     NaN     NaN
# 2011-12-08                 NaN     NaN     NaN     NaN     NaN     NaN
# 2011-12-13                 NaN     NaN     NaN     NaN     NaN     NaN
# ...                        ...     ...     ...     ...     ...     ...
# 2014-10-02                 NaN     NaN     NaN     NaN     NaN     NaN
# 2014-10-03                 NaN     NaN     NaN     NaN     NaN     NaN
# 2014-10-04                 1.0     1.0     NaN     NaN     NaN     NaN
# 2014-10-05                 NaN     NaN     NaN     NaN     NaN     NaN
# 2014-10-06                 NaN     NaN     1.0     NaN     NaN     1.0
#
# Member                  M99030  M99206
# corrected_Created_date
# 2011-12-03                 NaN     NaN
# 2011-12-04                 NaN     NaN
# 2011-12-07                 NaN     NaN
# 2011-12-08                 NaN     NaN
# 2011-12-13                 NaN     NaN
# ...                        ...     ...
# 2014-10-02                 NaN     NaN
# 2014-10-03                 NaN     NaN
# 2014-10-04                 NaN     NaN
# 2014-10-05                 NaN     NaN
# 2014-10-06                 NaN     NaN
#
# [978 rows x 106 columns]

# %%
pd.pivot_table(filt_df,values='Order',index='corrected_Created_date',columns='Member',aggfunc='count').plot()
# Out:
# <Axes: xlabel='corrected_Created_date'>

# %% [markdown]
# Plotting the number of orders over time reveals seasonal patterns, spikes in purchase and the trend of a purchase by a particular customer.
# From the above plot, we can see that number of orders are more in the month of May and September. We can also see the customers with member ID M08075,M18732 and M31101 have ordered most number of times in the similar pattern. These customers are most likely will not churn

# %% [markdown]
# ### Calculate the moving average to find buying patter of each customer

# %%
member_df = filt_df.copy()
member_df.set_index('corrected_Created_date',inplace=True)
member_df.head()
# Out:
#                           Order  Member  \
# corrected_Created_date
# 2014-09-28              6422558  M27458
# 2014-09-28              6422636  M39021
# 2014-09-28              6423338  M36366
# 2014-09-28              6423534  M25900
# 2014-09-29              6423959  M57354
#
#                                                               Description  \
# corrected_Created_date
# 2014-09-28              Boiled Rice, Other Rice Products, Mosquito Rep...
# 2014-09-28              Sunflower Oils, Brinjals, Root Vegetables, Oth...
# 2014-09-28              Beans, Banana, Snacky Nuts, Cashews, Millet fl...
# 2014-09-28                    Facial Tissues, Organic F&V, Cakes, Cookies
# 2014-09-29              Other Pulses, Sunflower Oils, Snacks, Other Sw...
#
#                         Total_Items Member's Full Name  \
# corrected_Created_date
# 2014-09-28                        9    Melissa Nielsen
# 2014-09-28                       11   Kevin Pennington
# 2014-09-28                       12    Jessica Nichols
# 2014-09-28                        4     Jessica Guzman
# 2014-09-29                        4      Matthew Davis
#
#                                                        Member's Address  \
# corrected_Created_date
# 2014-09-28                     3260 Scott Fords, Port Richard, KY 71319
# 2014-09-28                        19919 Lara Ferry, Jonesfurt, WY 70455
# 2014-09-28                      43026 Fisher Mount, New Karen, KY 94332
# 2014-09-28              5071 Bell Knolls, Port Gabriellaburgh, AL 69223
# 2014-09-29              44842 Pamela Street, Port Natashafort, AL 87144
#
#                        Member's Gender corrected_members_dob  Age  \
# corrected_Created_date
# 2014-09-28                        Male            1996-02-16   27
# 2014-09-28                        Male            1911-04-30  112
# 2014-09-28                        Male            1924-10-02   98
# 2014-09-28                      Female            1953-08-01   70
# 2014-09-29                        Male            1951-11-12   71
#
#                        Member's Membership Level  Member's Purchase History  \
# corrected_Created_date
# 2014-09-28                                Silver                          0
# 2014-09-28                                  Gold                          8
# 2014-09-28                                Bronze                          3
# 2014-09-28                                  Gold                          7
# 2014-09-29                                Bronze                          5
#
#                         Order Value Payment Method Order Status
# corrected_Created_date
# 2014-09-28                      620         PayPal      Shipped
# 2014-09-28                      618    Credit Card    Delivered
# 2014-09-28                      295           Cash      Shipped
# 2014-09-28                      881    Credit Card      Pending
# 2014-09-29                      595           Cash    Delivered

# %% [markdown]
# #### Group by Member and calucate the moving average of total items bought by each customer over 30 days window.

# %%
member_df['SMA30'] = member_df.groupby('Member')['Total_Items'].transform(lambda x: x.rolling(30).mean())
member_df.dropna(inplace=True)
member_df
# Out:
#                           Order  Member  \
# corrected_Created_date
# 2014-07-19              6691796  M09303
# 2014-07-22              6699324  M36432
# 2014-07-22              6699488  M36432
# 2014-07-22              6699907  M36432
# 2014-07-22              6701806  M09303
# ...                         ...     ...
# 2013-11-20              8387964  M90375
# 2013-11-20              8387967  M44156
# 2013-11-19              8388196  M91098
# 2013-11-19              8388442  M54345
# 2013-11-19              8388492  M39021
#
#                                                               Description  \
# corrected_Created_date
# 2014-07-19              Banana, Ayurvedic Food, Jaggery, Organic Brand...
# 2014-07-22                                                          Beans
# 2014-07-22                                                   Millet flour
# 2014-07-22              Whole Spices, Whole Spices, Gourd & Cucumber, ...
# 2014-07-22              Snacks, Cream Biscuits, Whole Spices, Gourd & ...
# ...                                                                   ...
# 2013-11-20              Organic F&V, Other Rice Products, Other Vegeta...
# 2013-11-20              Brinjals, Brinjals, Banana, Gourd & Cucumber, ...
# 2013-11-19              Sunflower Oils, Boiled Rice, Whole Spices, Mil...
# 2013-11-19              Other Pulses, Tissue Paper & Napkins, Tissue P...
# 2013-11-19              Beans, Urad Dal, Mosquito Repellent, Brinjals,...
#
#                         Total_Items   Member's Full Name  \
# corrected_Created_date
# 2014-07-19                        5         Malik Taylor
# 2014-07-22                        1  Catherine Blackburn
# 2014-07-22                        1        Cathy Farrell
# 2014-07-22                        7           Eric Yoder
# 2014-07-22                        8          Howard Ross
# ...                             ...                  ...
# 2013-11-20                        3         April Nelson
# 2013-11-20                        6        Deborah Brown
# 2013-11-19                        7          Tyler Velez
# 2013-11-19                       24      Curtis Martinez
# 2013-11-19                       13     Christine Arnold
#
#                                                          Member's Address  \
# corrected_Created_date
# 2014-07-19                              485 Shaun Ford, Coxside, HI 69910
# 2014-07-22                      3011 Joseph Terrace, Wrightfurt, SC 16650
# 2014-07-22                        03744 Myers Flats, East Maria, WA 51966
# 2014-07-22                     81730 Roger Brook, Rodriguezside, VI 54269
# 2014-07-22                         6325 Carlson Isle, Jacobbury, WI 21222
# ...                                                                   ...
# 2013-11-20              6346 Faulkner Oval Suite 220, Jeffreyborough, ...
# 2013-11-20              051 Schwartz Causeway Suite 430, Rothport, CO ...
# 2013-11-19                        837 Rodriguez Burg, North Roy, NV 81841
# 2013-11-19              4228 Figueroa Viaduct Suite 096, Prattville, C...
# 2013-11-19                        477 Pham Flat, New Donnaville, NE 46594
#
#                        Member's Gender corrected_members_dob  Age  \
# corrected_Created_date
# 2014-07-19                      Female            1953-12-31   69
# 2014-07-22                        Male            1922-06-10  101
# 2014-07-22                      Female            2014-10-07    8
# 2014-07-22                      Female            1977-02-04   46
# 2014-07-22                      Female            1969-07-28   54
# ...                                ...                   ...  ...
# 2013-11-20                        Male            1987-05-20   36
# 2013-11-20                        Male            2013-04-28   10
# 2013-11-19                      Female            1947-01-11   76
# 2013-11-19                        Male            1921-12-18  101
# 2013-11-19                      Female            2001-03-01   22
#
#                        Member's Membership Level  Member's Purchase History  \
# corrected_Created_date
# 2014-07-19                                  Gold                          9
# 2014-07-22                                Silver                          8
# 2014-07-22                                  Gold                          8
# 2014-07-22                                Bronze                          2
# 2014-07-22                                Silver                          4
# ...                                          ...                        ...
# 2013-11-20                                Bronze                          3
# 2013-11-20                                  Gold                          2
# 2013-11-19                                Silver                          8
# 2013-11-19                                  Gold                          9
# 2013-11-19                                Silver                          8
#
#                         Order Value Payment Method Order Status     SMA30
# corrected_Created_date
# 2014-07-19                      458           Cash      Shipped  4.166667
# 2014-07-22                      104    Credit Card      Shipped  4.666667
# 2014-07-22                      787           Cash    Delivered  4.666667
# 2014-07-22                      380           Cash      Pending  4.700000
# 2014-07-22                      256         PayPal      Pending  4.400000
# ...                             ...            ...          ...       ...
# 2013-11-20                      370           Cash    Delivered  4.566667
# 2013-11-20                      995           Cash      Shipped  7.266667
# 2013-11-19                      697         PayPal      Pending  7.300000
# 2013-11-19                      431    Credit Card    Delivered  8.666667
# 2013-11-19                      579         PayPal      Shipped  9.400000
#
# [5322 rows x 15 columns]

# %%
cust1_df = member_df[member_df['Member'] == 'M09303']
cust1_df[['Total_Items', 'SMA30']].plot(label='Member',figsize=(16, 8))
# Out:
# <Axes: xlabel='corrected_Created_date'>

# %% [markdown]
# The spend pattern for customer 'M09303'shows more upward peaks which indicates that this customer purchases more frequently.

# %% [markdown]
# #### Customer Segmentation based on order value

# %%
age18_25 = filt_df.Age[(filt_df.Age <= 25) & (filt_df.Age >= 18)]
age26_35 = filt_df.Age[(filt_df.Age <= 35) & (filt_df.Age >= 26)]
age36_45 = filt_df.Age[(filt_df.Age <= 45) & (filt_df.Age >= 36)]
age46_55 = filt_df.Age[(filt_df.Age <= 55) & (filt_df.Age >= 46)]
age55above = filt_df.Age[filt_df.Age >= 56]

# %%
x = ["18-25","26-35","36-45","46-55","55+"]
y = [len(age18_25.values),len(age26_35.values),len(age36_45.values),len(age46_55.values),len(age55above.values)]

plt.figure(figsize=(15,6))
sns.barplot(x=x, y=y, palette="rocket")
plt.title("Number of Customer and Ages")
plt.xlabel("Age")
plt.ylabel("Number of Customer")
plt.show()

# %% [markdown]
# We see the distribution of customer based on there ages. We see that customer with age group above 55 are more dominant purchasers

# %% [markdown]
# #### Customer vs Order Values

# %%
filt_df['Order Value'].min()
# Out:
# 10

# %%
filt_df['Order Value'].max()
# Out:
# 1000

# %%
ss10_200 = filt_df["Order Value"][(filt_df["Order Value"] >= 10) & (filt_df["Order Value"] <= 200)]
ss201_400 = filt_df["Order Value"][(filt_df["Order Value"] >= 201) & (filt_df["Order Value"] <= 400)]
ss401_600 = filt_df["Order Value"][(filt_df["Order Value"] >= 401) & (filt_df["Order Value"] <= 600)]
ss601_800 = filt_df["Order Value"][(filt_df["Order Value"] >= 601) & (filt_df["Order Value"] <= 800)]
ss801_1000 = filt_df["Order Value"][(filt_df["Order Value"] >= 801) & (filt_df["Order Value"] <= 1000)]

ssx = ["10-202", "201-400", "401-600", "601-800", "801-1000"]
ssy = [len(ss10_200.values), len(ss201_400.values), len(ss401_600.values), len(ss601_800.values), len(ss801_1000.values)]

plt.figure(figsize=(15,6))
sns.barplot(x=ssx, y=ssy, palette="nipy_spectral_r")
plt.title("Spending distribution")
plt.xlabel("Order Value")
plt.ylabel("Number of Customer")
plt.show()

# %% [markdown]
# Majority of the customers spend in the range of $200 to $400

# %% [markdown]
# #### Customer grouping based on purchase behaviour

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
cust_seg_df = filt_df[['Member\'s Gender','Age','Member\'s Membership Level','Order Value']]
cust_seg_df['Gender_Encoded'] = label_encoder.fit_transform(cust_seg_df['Member\'s Gender'])
cust_seg_df['Membership_Encoded'] = label_encoder.fit_transform(cust_seg_df['Member\'s Membership Level'])
cust_seg_df.drop(['Member\'s Gender','Member\'s Membership Level'],axis=1,inplace=True)
cust_seg_df.head()
# Out:
# C:\Users\ic016726\AppData\Local\Temp\ipykernel_146428\4133875459.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_seg_df['Gender_Encoded'] = label_encoder.fit_transform(cust_seg_df['Member\'s Gender'])
# C:\Users\ic016726\AppData\Local\Temp\ipykernel_146428\4133875459.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_seg_df['Membership_Encoded'] = label_encoder.fit_transform(cust_seg_df['Member\'s Membership Level'])
# C:\Users\ic016726\AppData\Local\Temp\ipykernel_146428\4133875459.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_seg_df.drop(['Member\'s Gender','Member\'s Membership Level'],axis=1,inplace=True)
#    Age  Order Value  Gender_Encoded  Membership_Encoded
# 0   27          620               1                   2
# 1  112          618               1                   1
# 2   98          295               1                   0
# 3   70          881               0                   1
# 4   71          595               1                   0

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=5)
clusters = km.fit_predict(cust_seg_df)
cust_seg_df["label"] = clusters

from mpl_toolkits.mplot3d import Axes3D
 
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(cust_seg_df.Age[cust_seg_df.label == 0], cust_seg_df["Membership_Encoded"][cust_seg_df.label == 0], cust_seg_df["Order Value"][cust_seg_df.label == 0], c='blue', s=60)
ax.scatter(cust_seg_df.Age[cust_seg_df.label == 1], cust_seg_df["Membership_Encoded"][cust_seg_df.label == 1], cust_seg_df["Order Value"][cust_seg_df.label == 1], c='red', s=60)
ax.scatter(cust_seg_df.Age[cust_seg_df.label == 2], cust_seg_df["Membership_Encoded"][cust_seg_df.label == 2], cust_seg_df["Order Value"][cust_seg_df.label == 2], c='green', s=60)
ax.scatter(cust_seg_df.Age[cust_seg_df.label == 3], cust_seg_df["Membership_Encoded"][cust_seg_df.label == 3], cust_seg_df["Order Value"][cust_seg_df.label == 3], c='orange', s=60)
ax.scatter(cust_seg_df.Age[cust_seg_df.label == 4], cust_seg_df["Membership_Encoded"][cust_seg_df.label == 4], cust_seg_df["Order Value"][cust_seg_df.label == 4], c='purple', s=60)
ax.view_init(30, 185)
plt.xlabel("Age")
plt.ylabel("Membership")
ax.set_zlabel('Order Value')
plt.show()
# Out:
# C:\Users\ic016726\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\ic016726\AppData\Local\Temp\ipykernel_146428\3100043072.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_seg_df["label"] = clusters

# %%
pd.pivot_table(cust_seg_df,values='Order Value',index='Membership_Encoded',columns='label',aggfunc=np.mean)
# Out:
# label                        0           1           2           3           4
# Membership_Encoded
# 0                   110.695804  708.187970  307.748593  503.956522  898.835539
# 1                   110.188811  706.842308  309.490725  504.901695  900.978062
# 2                   111.392540  711.697324  308.955857  505.728814  903.378092

# %% [markdown]
# We have clustered the Customer based on age, membership and order Value using Kmeans clustering. We see that customer with Gold(1) and Silver(2) membership create High order values. Also people belonging to Cluster Group 1 and 3 produce more CLV to the company.

# %% [markdown]
# ##### Analyze customer behavior based on Recency, Frequency, and Monetary value

# %%
filt_df['corrected_Created_date'].min()
# Out:
# Timestamp('2011-12-03 00:00:00')

# %%
recency_df = filt_df.groupby(['Member\'s Full Name'])['corrected_Created_date'].max().reset_index()
current_date = datetime.now()
recency_df['Recency (Days)'] = (current_date - recency_df['corrected_Created_date']).dt.days
recency_df.head()
# Out:
#   Member's Full Name corrected_Created_date  Recency (Days)
# 0     Aaron Arellano             2014-01-07            3498
# 1       Aaron Benton             2013-07-18            3671
# 2    Aaron Gallagher             2014-03-12            3434
# 3     Aaron Harrison             2013-03-11            3800
# 4        Aaron Hayes             2013-09-08            3619

# %%
recency_df.describe()
# Out:
#        Recency (Days)
# count     7947.000000
# mean      3595.958727
# std        236.378379
# min       3226.000000
# 25%       3397.000000
# 50%       3573.000000
# 75%       3761.000000
# max       4264.000000

# %% [markdown]
# Recency determine how recently a customer made a purchase. We will use this data to further segment if they churned or not churned.

# %%
frequency_df = filt_df.groupby('Member\'s Full Name')['corrected_Created_date'].count().reset_index()

# %%
frequency_df.columns = ['Member\'s Full Name', 'Purchase Frequency']

# %%
frequency_df.describe()
# Out:
#        Purchase Frequency
# count         7947.000000
# mean             1.055367
# std              0.269154
# min              1.000000
# 25%              1.000000
# 50%              1.000000
# 75%              1.000000
# max              5.000000

# %% [markdown]
# Frequency of purchase shows how often customers make a purchase. We will use this data to further segment if they churn or not churn

# %%
monetary_df = filt_df.groupby('Member\'s Full Name')['Order Value'].sum().reset_index()
monetary_df.columns = ['Member\'s Full Name', 'CLV']
monetary_df.head()
# Out:
#   Member's Full Name  CLV
# 0     Aaron Arellano  190
# 1       Aaron Benton  514
# 2    Aaron Gallagher  592
# 3     Aaron Harrison  349
# 4        Aaron Hayes  893

# %%
monetary_df.describe()
# Out:
#                CLV
# count  7947.000000
# mean    530.105826
# std     320.177597
# min      10.000000
# 25%     265.000000
# 50%     516.000000
# 75%     776.000000
# max    2754.000000

# %%
monetary_df[monetary_df['CLV']==10]
# Out:
#      Member's Full Name  CLV
# 799        Billy Bryant   10
# 2842       Harold Smith   10
# 3054       James Greene   10
# 3991     Juan Robertson   10
# 6904     Shannon Bowman   10

# %%
monetary_df[monetary_df['CLV']==2754]
# Out:
#      Member's Full Name   CLV
# 6351      Richard Allen  2754

# %% [markdown]
# the Customer Lifetime Value for each customer, which represents the potential value a customer brings to the company over time.

# %% [markdown]
# #### Customer Segmentation and deciding which group will churn and which group will not churn

# %% [markdown]
# Choosing Customer Full name, Gender, Age, Membership Level, Total Items, Order Value, Recency, Frequency of Purchase and CLV for segmentation

# %%
cust_seg_df = filt_df[['Member\'s Full Name','Member\'s Gender','Age','Member\'s Membership Level','Total_Items','Order Value']]
cust_seg_df.head()
# Out:
#   Member's Full Name Member's Gender  Age Member's Membership Level  \
# 0    Melissa Nielsen            Male   27                    Silver
# 1   Kevin Pennington            Male  112                      Gold
# 2    Jessica Nichols            Male   98                    Bronze
# 3     Jessica Guzman          Female   70                      Gold
# 4      Matthew Davis            Male   71                    Bronze
#
#    Total_Items  Order Value
# 0            9          620
# 1           11          618
# 2           12          295
# 3            4          881
# 4            4          595

# %%
# Merge the Recency df and Frequency df to get the Recency and frequency of items purchased
merge_df = pd.merge(recency_df,frequency_df,on='Member\'s Full Name')

# %%
# Merge the monetary df to get the CLV
merge_df = pd.merge(merge_df,monetary_df,on='Member\'s Full Name')

# %%
merge_df.head()
# Out:
#   Member's Full Name corrected_Created_date  Recency (Days)  \
# 0     Aaron Arellano             2014-01-07            3498
# 1       Aaron Benton             2013-07-18            3671
# 2    Aaron Gallagher             2014-03-12            3434
# 3     Aaron Harrison             2013-03-11            3800
# 4        Aaron Hayes             2013-09-08            3619
#
#    Purchase Frequency  CLV
# 0                   1  190
# 1                   1  514
# 2                   1  592
# 3                   1  349
# 4                   1  893

# %%
# merge with Main data frame to procede with Kmeans clustering 
segmnt_df = pd.merge(cust_seg_df,merge_df,on='Member\'s Full Name')

# %%
segmnt_df.head()
# Out:
#   Member's Full Name Member's Gender  Age Member's Membership Level  \
# 0    Melissa Nielsen            Male   27                    Silver
# 1   Kevin Pennington            Male  112                      Gold
# 2    Jessica Nichols            Male   98                    Bronze
# 3     Jessica Guzman          Female   70                      Gold
# 4      Matthew Davis            Male   71                    Bronze
#
#    Total_Items  Order Value corrected_Created_date  Recency (Days)  \
# 0            9          620             2014-09-28            3234
# 1           11          618             2014-09-28            3234
# 2           12          295             2014-09-28            3234
# 3            4          881             2014-09-28            3234
# 4            4          595             2014-09-29            3233
#
#    Purchase Frequency  CLV
# 0                   1  620
# 1                   1  618
# 2                   1  295
# 3                   1  881
# 4                   2  956

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
segmnt_df['Gender_Encoded'] = label_encoder.fit_transform(segmnt_df['Member\'s Gender'])
segmnt_df['Membership_Encoded'] = label_encoder.fit_transform(segmnt_df['Member\'s Membership Level'])
segmnt_df.drop(['Member\'s Gender','Member\'s Membership Level','corrected_Created_date'],axis=1,inplace=True)
segmnt_df.head()
# Out:
#   Member's Full Name  Age  Total_Items  Order Value  Recency (Days)  \
# 0    Melissa Nielsen   27            9          620            3234
# 1   Kevin Pennington  112           11          618            3234
# 2    Jessica Nichols   98           12          295            3234
# 3     Jessica Guzman   70            4          881            3234
# 4      Matthew Davis   71            4          595            3233
#
#    Purchase Frequency  CLV  Gender_Encoded  Membership_Encoded
# 0                   1  620               1                   2
# 1                   1  618               1                   1
# 2                   1  295               1                   0
# 3                   1  881               0                   1
# 4                   2  956               1                   0

# %% [markdown]
# ###### Perform kmeans clustring to segment the customers

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=2)
clusters = km.fit_predict(segmnt_df.iloc[:,1:])
segmnt_df["label"] = clusters
segmnt_df.head()
# Out:
# C:\Users\ic016726\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#   Member's Full Name  Age  Total_Items  Order Value  Recency (Days)  \
# 0    Melissa Nielsen   27            9          620            3234
# 1   Kevin Pennington  112           11          618            3234
# 2    Jessica Nichols   98           12          295            3234
# 3     Jessica Guzman   70            4          881            3234
# 4      Matthew Davis   71            4          595            3233
#
#    Purchase Frequency  CLV  Gender_Encoded  Membership_Encoded  label
# 0                   1  620               1                   2      1
# 1                   1  618               1                   1      1
# 2                   1  295               1                   0      0
# 3                   1  881               0                   1      1
# 4                   2  956               1                   0      1

# %%
segment0_df = segmnt_df[segmnt_df['label']==0]
segment1_df = segmnt_df[segmnt_df['label']==1]

# %%
print(segment0_df.shape)
print(segment1_df.shape)
# Out:
# (4255, 10)
# (4132, 10)

# %%
segment0_df.describe()
# Out:
#                Age  Total_Items  Order Value  Recency (Days)  \
# count  4255.000000  4255.000000  4255.000000     4255.000000
# mean     58.116804     7.432197   269.392949     3595.795770
# std      33.401509     5.046940   150.823459      236.910427
# min      -1.000000     1.000000    10.000000     3226.000000
# 25%      30.000000     4.000000   138.500000     3398.000000
# 50%      58.000000     7.000000   267.000000     3570.000000
# 75%      87.000000    10.000000   398.000000     3761.000000
# max     116.000000    42.000000   543.000000     4259.000000
#
#        Purchase Frequency          CLV  Gender_Encoded  Membership_Encoded  \
# count         4255.000000  4255.000000     4255.000000         4255.000000
# mean             1.047474   284.189424        0.491422            1.006580
# std              0.233738   160.325208        0.499985            0.812719
# min              1.000000    10.000000        0.000000            0.000000
# 25%              1.000000   149.500000        0.000000            0.000000
# 50%              1.000000   285.000000        0.000000            1.000000
# 75%              1.000000   415.000000        1.000000            2.000000
# max              4.000000   918.000000        1.000000            2.000000
#
#         label
# count  4255.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0

# %%
segment1_df.describe()
# Out:
#                Age  Total_Items  Order Value  Recency (Days)  \
# count  4132.000000  4132.000000  4132.000000     4132.000000
# mean     57.605760     7.385528   742.130687     3581.141578
# std      33.578383     4.871251   170.229648      233.419378
# min      -1.000000     1.000000    11.000000     3226.000000
# 25%      29.000000     4.000000   633.750000     3383.000000
# 50%      58.000000     7.000000   756.000000     3556.000000
# 75%      87.000000    10.000000   875.000000     3739.250000
# max     116.000000    35.000000  1000.000000     4264.000000
#
#        Purchase Frequency          CLV  Gender_Encoded  Membership_Encoded  \
# count         4132.000000  4132.000000     4132.000000         4132.000000
# mean             1.202807   848.940949        0.481123            1.024443
# std              0.543897   276.154928        0.499704            0.816279
# min              1.000000   536.000000        0.000000            0.000000
# 25%              1.000000   680.750000        0.000000            0.000000
# 50%              1.000000   804.000000        0.000000            1.000000
# 75%              1.000000   927.250000        1.000000            2.000000
# max              5.000000  2754.000000        1.000000            2.000000
#
#         label
# count  4132.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0

# %% [markdown]
# ###### Using Kmeans clustering we have segmented the customer base into 2 groups based on Age, Total_Items purchased, Order Value, Recency, Purchase Frequency, CLV, Gender and Membership.
# ###### After segmenting we see that Segment with label 0 and label 1 differ a lot in Order Value,Purchase Frequency and CLV.
# ###### The average Order Value of the customers in the group 1 is higher than group 0 customers by 36.31% .
# ###### The average Purchase Frequency of customer in the group 1 is higher than group 0 customers by 86.6 %.
# ###### The average CLV of customer in the group 1 is higher than group 0 customers by 33.48 %
#
# ###### From the above inference we can see that customers in the group 0 does not produce higher Order value, there purchase frequency is less and customer life time value (CLV) is also less compared to customers in group 1. Through this inferece we can conclude that customer in group 0 are more likely to churn out. The organisation should focus on retaining the customers in the group 1 and try to by providing better product recommendation based on the spending pattern analysed above to both the customer group 0 so the people from group 0 does not churn

# %% [markdown]
# ## Customer Churn Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score,confusion_matrix,f1_score,accuracy_score
from fairlearn.metrics import selection_rate, MetricFrame
from sklearn.metrics import accuracy_score, recall_score, precision_score

# %%
segmnt_df.head()
# Out:
#   Member's Full Name  Age  Total_Items  Order Value  Recency (Days)  \
# 0    Melissa Nielsen   27            9          620            3234
# 1   Kevin Pennington  112           11          618            3234
# 2    Jessica Nichols   98           12          295            3234
# 3     Jessica Guzman   70            4          881            3234
# 4      Matthew Davis   71            4          595            3233
#
#    Purchase Frequency  CLV  Gender_Encoded  Membership_Encoded  label
# 0                   1  620               1                   2      1
# 1                   1  618               1                   1      1
# 2                   1  295               1                   0      0
# 3                   1  881               0                   1      1
# 4                   2  956               1                   0      1

# %%
X = segmnt_df.iloc[:,1:-1]
y = segmnt_df.iloc[:,-1]

# %%
s = segmnt_df[['Age']]
# Change value to represent age groups
s['Age'] = np.where(s.Age > 58,'Over 58', '58 or younger') # because 58 is the average age of customer from the data analysis
s['Age'].value_counts()
# Out:
# C:\Users\ic016726\AppData\Local\Temp\ipykernel_146428\2636930148.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s['Age'] = np.where(s.Age > 58,'Over 58', '58 or younger') # because 58 is the average age of customer from the data analysis
# 58 or younger    4225
# Over 58          4162
# Name: Age, dtype: int64

# %%
G = segmnt_df[['Gender_Encoded']]
G['Gender_Encoded'].value_counts()# 0 is Female and 1 is Male
# Out:
# 0    4308
# 1    4079
# Name: Gender_Encoded, dtype: int64

# %%
X_train, X_test, y_train, y_test,S_train,S_test,G_train,G_test = train_test_split(X, y,s,G, test_size=0.2, random_state=0, stratify=y)

churn_model = DecisionTreeClassifier(max_depth=50, min_samples_split=50, min_samples_leaf=25,
                                  max_leaf_nodes=100, class_weight='balanced', ccp_alpha=0.0001).fit(X_train, y_train)

# %%
X_train.shape
# Out:
# (6709, 8)

# %%
X_test.shape
# Out:
# (1678, 8)

# %%
churn_model = DecisionTreeClassifier(max_depth=50, min_samples_split=50, min_samples_leaf=25,
                                  max_leaf_nodes=100, class_weight='balanced', ccp_alpha=0.0001).fit(X_train, y_train)

# %%
y_hat = churn_model.predict(X_test)

# %%
# Get overall metrics
print("Overall Metrics:")
# Get selection rate from fairlearn
overall_selection_rate = selection_rate(y_test, y_hat) # Get selection rate from fairlearn
print("\tSelection Rate:", overall_selection_rate)
# Get standard metrics from scikit-learn
overall_accuracy = accuracy_score(y_test, y_hat)
print("\tAccuracy:", overall_accuracy)
overall_recall = recall_score(y_test, y_hat)
print("\tRecall:", overall_recall)
overall_precision = precision_score(y_test, y_hat)
print("\tPrecision:", overall_precision)

# Get metrics by sensitive group from fairlearn
print('\nMetrics by Group:')
metrics = {'selection_rate': selection_rate,
           'accuracy': accuracy_score,
           'recall': recall_score,
           'precision': precision_score}

group_metrics = MetricFrame(metrics=metrics,
                             y_true=y_test,
                             y_pred=y_hat,
                             sensitive_features=S_test)

group_metrics1 = MetricFrame(metrics=metrics,
                             y_true=y_test,
                             y_pred=y_hat,
                             sensitive_features=G_test)

print(group_metrics.by_group)
print(group_metrics1.by_group)
# Out:
# Overall Metrics:
# 	Selection Rate: 0.49523241954707986
# 	Accuracy: 0.9928486293206198
# 	Recall: 0.9951632406287787
# 	Precision: 0.9903730445246691
#
# Metrics by Group:
#                selection_rate  accuracy    recall  precision
# Age
# 58 or younger        0.489336  0.995261  0.992771   0.997579
# Over 58              0.501199  0.990408  0.997573   0.983254
#                 selection_rate  accuracy    recall  precision
# Gender_Encoded
# 0                      0.50348  0.993039  0.993088   0.993088
# 1                      0.48652  0.992647  0.997455   0.987406

# %% [markdown]
# - in above we can see that in Age our model selection rate is for 58 or younger is **48%** and for over 58 is **50%** significantly different between different groups, it  indicates that our model is NOT biased. The model is not biased for Gender as well
#
# - In this scenario, consider *recall*. This metric indicates the proportion of churn  cases that were correctly identified by the model. In other words, of all the customers who are actually churn, how many did the model find? The model does a best for all age group and both the gender.

# %% [markdown]
# # Assignment - Part 2

# %%
df.head()
# Out:
#      Order  Member                                                SKU  \
# 0  6422558  M27458  15669789, 15669830, 34993978, 15669856, 775378...
# 1  6422636  M39021  7580802, 15668453, 15668375, 15668379, 1566976...
# 2  6423338  M36366  15668469, 15668478, 7586314, 15669800, 1566978...
# 3  6423534  M25900              34987356, 15670251, 7585573, 34992815
# 4  6423959  M57354               34989501, 7580811, 7569799, 34938526
#
#    Created On                                        Description  \
# 0  28-09-2014  Boiled Rice, Other Rice Products, Mosquito Rep...
# 1  28-09-2014  Sunflower Oils, Brinjals, Root Vegetables, Oth...
# 2  28-09-2014  Beans, Banana, Snacky Nuts, Cashews, Millet fl...
# 3  28-09-2014        Facial Tissues, Organic F&V, Cakes, Cookies
# 4  29-09-2014  Other Pulses, Sunflower Oils, Snacks, Other Sw...
#
#   Member's Full Name                                 Member's Address  \
# 0    Melissa Nielsen         3260 Scott Fords, Port Richard, KY 71319
# 1   Kevin Pennington            19919 Lara Ferry, Jonesfurt, WY 70455
# 2    Jessica Nichols          43026 Fisher Mount, New Karen, KY 94332
# 3     Jessica Guzman  5071 Bell Knolls, Port Gabriellaburgh, AL 69223
# 4      Matthew Davis  44842 Pamela Street, Port Natashafort, AL 87144
#
#                Member's Email Member's Phone Number Member's Gender  ...  \
# 0          tina64@example.org         (981)315-0970            Male  ...
# 1      lisahorton@example.com     (808)745-0768x733            Male  ...
# 2  gordoncourtney@example.com   (912)707-8569x14006            Male  ...
# 3           ibell@example.com         (722)989-7498          Female  ...
# 4         nancy96@example.net     972-960-4816x5421            Male  ...
#
#   Member's Purchase History Order Value  Payment Method  \
# 0                         0         620          PayPal
# 1                         8         618     Credit Card
# 2                         3         295            Cash
# 3                         7         881     Credit Card
# 4                         5         595            Cash
#
#                                     Delivery Address Order Status  \
# 0                   Unit 9405 Box 3979, DPO AA 03716      Shipped
# 1                   PSC 8209, Box 7092, APO AP 28287    Delivered
# 2  666 Jennifer Mills Suite 089, New Travis, VI 9...      Shipped
# 3  0279 Jason Forges Apt. 497, Andrewsborough, NV...      Pending
# 4    5038 Shane Rue Apt. 867, East Kenneth, AK 08214    Delivered
#
#   Credit Card Number corrected_Created_date  corrected_members_dob  \
# 0                NaN             2014-09-28             1996-02-16
# 1       3.509367e+15             2014-09-28             1911-04-30
# 2                NaN             2014-09-28             1924-10-02
# 3       2.581849e+15             2014-09-28             1953-08-01
# 4                NaN             2014-09-29             1951-11-12
#
#   Total_Items  Age
# 0           9   27
# 1          11  112
# 2          12   98
# 3           4   70
# 4           4   71
#
# [5 rows x 22 columns]

# %%
# Step 2: Identify Sensitive Columns
sensitive_columns = ["Member's Full Name", "Member's Address", "Member's Email", "Member's Phone Number", 
                     "Credit Card Number", "Delivery Address"]

# Create age bins and group members based on their age
age_bins = [0,18, 25, 35, 45, 55, float('inf')]
age_labels = ['0-18', '19-25', '26-35', '36-45', '46-55', '55+']
df['Age Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=False)
df.drop(columns=["Age"], inplace=True)
df.drop(columns=["corrected_Created_date"], inplace=True)
df.drop(columns=["Member's Date of Birth"], inplace=True)
df.drop(columns=["corrected_members_dob"], inplace=True)

# Step 3b: Suppression
df.drop(columns=sensitive_columns, inplace=True)

df.head()
# Out:
#      Order  Member                                                SKU  \
# 0  6422558  M27458  15669789, 15669830, 34993978, 15669856, 775378...
# 1  6422636  M39021  7580802, 15668453, 15668375, 15668379, 1566976...
# 2  6423338  M36366  15668469, 15668478, 7586314, 15669800, 1566978...
# 3  6423534  M25900              34987356, 15670251, 7585573, 34992815
# 4  6423959  M57354               34989501, 7580811, 7569799, 34938526
#
#    Created On                                        Description  \
# 0  28-09-2014  Boiled Rice, Other Rice Products, Mosquito Rep...
# 1  28-09-2014  Sunflower Oils, Brinjals, Root Vegetables, Oth...
# 2  28-09-2014  Beans, Banana, Snacky Nuts, Cashews, Millet fl...
# 3  28-09-2014        Facial Tissues, Organic F&V, Cakes, Cookies
# 4  29-09-2014  Other Pulses, Sunflower Oils, Snacks, Other Sw...
#
#   Member's Gender Member's Membership Level  Member's Purchase History  \
# 0            Male                    Silver                          0
# 1            Male                      Gold                          8
# 2            Male                    Bronze                          3
# 3          Female                      Gold                          7
# 4            Male                    Bronze                          5
#
#    Order Value Payment Method Order Status  Total_Items Age Group
# 0          620         PayPal      Shipped            9     26-35
# 1          618    Credit Card    Delivered           11       55+
# 2          295           Cash      Shipped           12       55+
# 3          881    Credit Card      Pending            4       55+
# 4          595           Cash    Delivered            4       55+

# %%
df.to_csv('Data_Ethics_Assignment_Part_2_DeidentifiedOutput.csv', index=False) # saving the final output file
